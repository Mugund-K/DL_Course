# %% [markdown]
# <a href="https://colab.research.google.com/github/Mugund-K/DL_Course/blob/main/plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.random((10,1))
x
# Out:
# array([[0.48840382],
#        [0.91182664],
#        [0.14448025],
#        [0.66945211],
#        [0.65511032],
#        [0.73725888],
#        [0.86272259],
#        [0.83243549],
#        [0.47708717],
#        [0.11854469]])

# %%
plt.plot(x, '*-')
plt.show()

# %%
x =np.linspace(0, 100, 50)
y = np.power(x, 2)
plt.plot(x,y, '+')
plt.show()

# %%
import seaborn as sns
sns.set()

# %%
sns.lineplot(x, y)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# !ls
# Out:
# mobile_cleaned.csv  sample_data

# %%
import pandas as pd
data = pd.read_csv('mobile_cleaned.csv')
data
# Out:
#      PhoneId  Pixel Density  Screen Size  ...  Sim1_3G  Sim1_4G  Rating
# 0          0            403         6.26  ...        0        1     4.5
# 1          1            271         6.20  ...        0        1     4.5
# 2          2            409         6.30  ...        0        1     4.4
# 3          4            411         6.00  ...        0        1     4.3
# 4          5            396         6.50  ...        0        1     4.4
# ..       ...            ...          ...  ...      ...      ...     ...
# 336      465            220         5.00  ...        0        1     3.8
# 337      466            401         5.50  ...        0        1     3.9
# 338      468            282         5.20  ...        0        1     4.1
# 339      470            218         4.50  ...        0        1     3.6
# 340      472            401         5.50  ...        0        1     4.3
#
# [341 rows x 88 columns]

# %%
ax = sns.scatterplot(x="Weight", y="Resolution", data=data)

# %%
ax = sns.scatterplot(x="Weight", y="Resolution", hue="Internal Memory", data=data)

# %%
ax =sns.displot(data["Internal Memory"])

# %%
ax =sns.displot(data["Weight"], kde=False, rug=True)

# %%
ax= sns.boxplot(x='RAM', y='Weight', data=data)

# %%
ax= sns.boxplot(x='RAM', y='Rating', data=data)

# %%
uniform_data = np.random.rand(10, 12)
uniform_data
# Out:
# array([[2.06053419e-01, 8.31218498e-01, 5.53314780e-02, 3.74841872e-01,
#         1.76691448e-01, 8.02506499e-01, 3.39508456e-01, 2.79359583e-01,
#         9.06827597e-01, 8.05254680e-01, 6.75188561e-01, 2.98293234e-01],
#        [4.11268725e-01, 1.43764111e-01, 7.43950714e-01, 2.55527037e-01,
#         9.41020228e-01, 5.62341865e-01, 9.98613338e-01, 9.87622644e-01,
#         5.17464981e-01, 3.20495029e-01, 7.06013366e-01, 2.06125135e-02],
#        [5.85614390e-02, 2.17549046e-01, 1.39141908e-01, 5.84639091e-04,
#         9.82045264e-01, 1.46765456e-02, 8.67929762e-01, 9.41210842e-01,
#         7.06561243e-01, 9.09632538e-01, 8.46352700e-01, 1.74787390e-01],
#        [5.32399790e-01, 9.09858186e-01, 5.72475227e-01, 5.80653184e-01,
#         7.84749830e-01, 3.73717481e-01, 4.16752304e-01, 5.53197658e-01,
#         5.14346411e-01, 5.20672368e-01, 7.19854249e-01, 7.41174425e-01],
#        [9.97644650e-01, 6.40851474e-01, 1.23439506e-01, 5.01967144e-01,
# ...

# %%
ax=sns.heatmap(uniform_data, cmap="YlGnBu")

# %%
import matplotlib.image as mpimg
img = mpimg.imread('agency-logo.png')

# %%
print(img)
# Out:
# [[[0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   ...
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]]
#
#  [[0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   ...
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]]
#
#  [[0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   ...
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]
#   [0.11764706 0.27058825 0.627451   1.        ]]
#
#  ...
#
#  [[0.11764706 0.27058825 0.627451   1.        ]
# ...

# %%
imgplot = plt.imshow(img)
